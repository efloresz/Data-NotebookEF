# %%
import pandas as pd

# %%
file_path = '/Users/emilyflores/Desktop/Work/OAFall23/Data-NotebookEF/twcs.csv'
dataset = pd.read_csv('/Users/emilyflores/Desktop/Work/OAFall23/Data-NotebookEF/twcs.csv')

# %%
dataset.tail()
# Out:
#          tweet_id   author_id  inbound                      created_at  \
# 2811769   2987947  sprintcare    False  Wed Nov 22 08:43:51 +0000 2017
# 2811770   2987948      823869     True  Wed Nov 22 08:35:16 +0000 2017
# 2811771   2812240      121673     True  Thu Nov 23 04:13:07 +0000 2017
# 2811772   2987949      AldiUK    False  Wed Nov 22 08:31:24 +0000 2017
# 2811773   2987950      823870     True  Tue Nov 21 22:01:04 +0000 2017
#
#                                                       text response_tweet_id  \
# 2811769  @823869 Hey, we'd be happy to look into this f...               NaN
# 2811770  @115714 wtf!? I’ve been having really shitty s...           2987947
# 2811771  @143549 @sprintcare You have to go to https://...               NaN
# 2811772  @823870 Sounds delicious, Sarah! 😋 https://t.c...               NaN
# 2811773  @AldiUK  warm sloe gin mince pies with ice cre...   2987951,2987949
#
#          in_response_to_tweet_id
# 2811769                2987948.0
# ...

# %%
dataset.isnull()
# Out:
#          tweet_id  author_id  inbound  created_at   text  response_tweet_id  \
# 0           False      False    False       False  False              False
# 1           False      False    False       False  False               True
# 2           False      False    False       False  False              False
# 3           False      False    False       False  False              False
# 4           False      False    False       False  False              False
# ...           ...        ...      ...         ...    ...                ...
# 2811769     False      False    False       False  False               True
# 2811770     False      False    False       False  False              False
# 2811771     False      False    False       False  False               True
# 2811772     False      False    False       False  False               True
# 2811773     False      False    False       False  False              False
#
#          in_response_to_tweet_id
# ...

# %%
dataset.isna()
# Out:
#          tweet_id  author_id  inbound  created_at   text  response_tweet_id  \
# 0           False      False    False       False  False              False
# 1           False      False    False       False  False               True
# 2           False      False    False       False  False              False
# 3           False      False    False       False  False              False
# 4           False      False    False       False  False              False
# ...           ...        ...      ...         ...    ...                ...
# 2811769     False      False    False       False  False               True
# 2811770     False      False    False       False  False              False
# 2811771     False      False    False       False  False               True
# 2811772     False      False    False       False  False               True
# 2811773     False      False    False       False  False              False
#
#          in_response_to_tweet_id
# ...

# %%
dataset.isna().any()
# Out:
# tweet_id                   False
# author_id                  False
# inbound                    False
# created_at                 False
# text                       False
# response_tweet_id           True
# in_response_to_tweet_id     True
# dtype: bool

# %%
dataset.isna().sum()
# Out:
# tweet_id                         0
# author_id                        0
# inbound                          0
# created_at                       0
# text                             0
# response_tweet_id          1040629
# in_response_to_tweet_id     794335
# dtype: int64

# %%
dataset.isna().any().sum()
# Out:
# 2

# %%
dataset.duplicated()
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 2811769    False
# 2811770    False
# 2811771    False
# 2811772    False
# 2811773    False
# Length: 2811774, dtype: bool

# %%
dataset.drop_duplicates(subset=None, keep='first', inplace=False, ignore_index=False)
# Out:
#          tweet_id   author_id  inbound                      created_at  \
# 0               1  sprintcare    False  Tue Oct 31 22:10:47 +0000 2017
# 1               2      115712     True  Tue Oct 31 22:11:45 +0000 2017
# 2               3      115712     True  Tue Oct 31 22:08:27 +0000 2017
# 3               4  sprintcare    False  Tue Oct 31 21:54:49 +0000 2017
# 4               5      115712     True  Tue Oct 31 21:49:35 +0000 2017
# ...           ...         ...      ...                             ...
# 2811769   2987947  sprintcare    False  Wed Nov 22 08:43:51 +0000 2017
# 2811770   2987948      823869     True  Wed Nov 22 08:35:16 +0000 2017
# 2811771   2812240      121673     True  Thu Nov 23 04:13:07 +0000 2017
# 2811772   2987949      AldiUK    False  Wed Nov 22 08:31:24 +0000 2017
# 2811773   2987950      823870     True  Tue Nov 21 22:01:04 +0000 2017
#
#                                                       text response_tweet_id  \
# ...
